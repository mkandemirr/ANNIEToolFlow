# %%
import awkward as ak
import pandas as pd
import uproot
import numpy as np
import matplotlib.pyplot as plt

# %%
def CreateTreeAndGetEvents(path, treeName):
    file = uproot.open(path)
    tree = file.get(treeName)
    tree.show()
    events = tree.arrays(library = "ak")
    return events

mcPath = "/home/mutu/Desktop/RTE/build/CCFilteredMC.root"
#dataPath = "/home/mutu/Desktop/Fermilab-simulationStided/BeamClusterAnalysis/dowloandedFromgpvm/processed/yeniIndirilen/processingData_EBV2-BeamClusterTrees-R56*/R56.root"
treeName = "Event"

#events   = CreateTreeAndGetEvents(dataPath, treeName)
mcEvents = CreateTreeAndGetEvents(mcPath, treeName)
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# runNumber            | int32_t                  | AsDtype('>i4')
# subrunNumber         | int32_t                  | AsDtype('>i4')
# partFileNumber       | int32_t                  | AsDtype('>i4')
# runType              | int32_t                  | AsDtype('>i4')
# eventNumber          | int32_t                  | AsDtype('>i4')
# PrimaryTriggerWord   | int32_t                  | AsDtype('>i4')
# GroupedTriggerTime   | std::vector<uint64_t>    | AsJagged(AsDtype('>u8'), he...
# GroupedTriggerWord   | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# trigword             | int32_t                  | AsDtype('>i4')
# Extended             | int32_t                  | AsDtype('>i4')
# HasTank              | int32_t                  | AsDtype('>i4')
# HasMRD               | int32_t                  | AsDtype('>i4')
# HasLAPPD             | int32_t                  | AsDtype('>i4')
# TankMRDCoinc         | int32_t                  | AsDtype('>i4')
# NoVeto               | int32_t                  | AsDtype('>i4')
# MRDTriggerType       | int32_t                  | AsDtype('>i4')
# eventTimeTank        | uint64_t                 | AsDtype('>u8')
# eventTimeMRD         | uint64_t                 | AsDtype('>u8')
# beam_pot_875         | double                   | AsDtype('>f8')
# beam_ok              | int32_t                  | AsDtype('>i4')
# beam_E_TOR860        | double                   | AsDtype('>f8')
# beam_E_TOR875        | double                   | AsDtype('>f8')
# beam_THCURR          | double                   | AsDtype('>f8')
# beam_BTJT2           | double                   | AsDtype('>f8')
# beam_HP875           | double                   | AsDtype('>f8')
# beam_VP875           | double                   | AsDtype('>f8')
# beam_HPTG1           | double                   | AsDtype('>f8')
# beam_VPTG1           | double                   | AsDtype('>f8')
# beam_HPTG2           | double                   | AsDtype('>f8')
# beam_VPTG2           | double                   | AsDtype('>f8')
# beam_BTH2T2          | double                   | AsDtype('>f8')
# BeamInfoTime         | uint64_t                 | AsDtype('>u8')
# BeamInfoTimeToTri... | int64_t                  | AsDtype('>i8')
# numberOfClusters     | int32_t                  | AsDtype('>i4')
# clusterTime          | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# clusterCharge        | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# clusterPE            | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# clusterMaxPE         | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# clusterChargePointX  | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# clusterChargePointY  | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# clusterChargePointZ  | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# clusterChargeBalance | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# clusterHits          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# Cluster_HitX         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# Cluster_HitY         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# Cluster_HitZ         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# Cluster_HitT         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# Cluster_HitQ         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# Cluster_HitPE        | std::vector<std::vect... | AsObjects(AsVector(True, As...
# Cluster_HitType      | std::vector<std::vect... | AsObjects(AsVector(True, As...
# Cluster_HitDetID     | std::vector<std::vect... | AsObjects(AsVector(True, As...
# Cluster_HitChankey   | std::vector<std::vect... | AsObjects(AsVector(True, As...
# Cluster_HitChankeyMC | std::vector<std::vect... | AsObjects(AsVector(True, As...
# eventTimeMRD         | uint64_t                 | AsDtype('>u8')
# MRDClusterNumber     | int32_t                  | AsDtype('>i4')
# MRDClusterTime       | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDClusterTimeSigma  | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDClusterHitNumber  | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# nhits                | int32_t                  | AsDtype('>i4')
# filter               | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# hitX                 | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# hitY                 | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# hitZ                 | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# hitT                 | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# hitQ                 | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# hitPE                | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# hitType              | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# hitDetID             | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# hitChankey           | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# hitChankeyMC         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# LAPPDMCHitTubeIDs    | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# LAPPDMCHitChankeys   | std::vector<uint64_t>    | AsJagged(AsDtype('>u8'), he...
# LAPPDMCHitTime       | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# LAPPDMCHitCharge     | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# LAPPDMCHitX          | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# LAPPDMCHitY          | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# LAPPDMCHitZ          | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# LAPPDMCHitParalle... | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# LAPPDMCHitTransve... | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDHitClusterIndex   | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# MRDhitT              | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDHitCharge         | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDHitDigitPMT       | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# MRDhitDetID          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# MRDhitChankey        | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# MRDhitChankeyMC      | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# FMVhitT              | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# FMVhitDetID          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# FMVhitChankey        | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# FMVhitChankeyMC      | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# vetoHit              | int32_t                  | AsDtype('>i4')
# MRDClusterIndex      | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# NumClusterTracks     | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# MRDTrackAngle        | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDTrackAngleError   | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDPenetrationDepth  | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDTrackLength       | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDEntryPointRadius  | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDEnergyLoss        | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDEnergyLossError   | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDTrackStartX       | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDTrackStartY       | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDTrackStartZ       | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDTrackStopX        | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDTrackStopY        | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDTrackStopZ        | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# MRDSide              | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# MRDStop              | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# MRDThrough           | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# eventStatusApplied   | int32_t                  | AsDtype('>i4')
# eventStatusFlagged   | int32_t                  | AsDtype('>i4')
# triggerNumber        | int32_t                  | AsDtype('>i4')
# mcEntryNumber        | int32_t                  | AsDtype('>i4')
# trueVtxX             | double                   | AsDtype('>f8')
# trueVtxY             | double                   | AsDtype('>f8')
# trueVtxZ             | double                   | AsDtype('>f8')
# trueVtxTime          | double                   | AsDtype('>f8')
# trueDirX             | double                   | AsDtype('>f8')
# trueDirY             | double                   | AsDtype('>f8')
# trueDirZ             | double                   | AsDtype('>f8')
# trueAngle            | double                   | AsDtype('>f8')
# truePhi              | double                   | AsDtype('>f8')
# trueMuonEnergy       | double                   | AsDtype('>f8')
# truePrimaryPdg       | int32_t                  | AsDtype('>i4')
# trueTrackLengthIn... | double                   | AsDtype('>f8')
# trueTrackLengthInMRD | double                   | AsDtype('>f8')
# trueMultiRing        | int32_t                  | AsDtype('>i4')
# Pi0Count             | int32_t                  | AsDtype('>i4')
# PiPlusCount          | int32_t                  | AsDtype('>i4')
# PiMinusCount         | int32_t                  | AsDtype('>i4')
# K0Count              | int32_t                  | AsDtype('>i4')
# KPlusCount           | int32_t                  | AsDtype('>i4')
# KMinusCount          | int32_t                  | AsDtype('>i4')
# truePrimaryPdgs      | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# trueNeutCapVtxX      | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# trueNeutCapVtxY      | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# trueNeutCapVtxZ      | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# trueNeutCapNucleus   | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# trueNeutCapTime      | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# trueNeutCapGammas    | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# trueNeutCapE         | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# trueNeutCapGammaE    | std::vector<double>      | AsJagged(AsDtype('>f8'), he...
# trueNeutrinoEnergy   | double                   | AsDtype('>f8')
# trueNeutrinoMomen... | double                   | AsDtype('>f8')
# trueNeutrinoMomen... | double                   | AsDtype('>f8')
# trueNeutrinoMomen... | double                   | AsDtype('>f8')
# trueNuIntxVtx_X      | double                   | AsDtype('>f8')
# trueNuIntxVtx_Y      | double                   | AsDtype('>f8')
# trueNuIntxVtx_Z      | double                   | AsDtype('>f8')
# trueNuIntxVtx_T      | double                   | AsDtype('>f8')
# trueFSLVtx_X         | double                   | AsDtype('>f8')
# trueFSLVtx_Y         | double                   | AsDtype('>f8')
# trueFSLVtx_Z         | double                   | AsDtype('>f8')
# trueFSLMomentum_X    | double                   | AsDtype('>f8')
# trueFSLMomentum_Y    | double                   | AsDtype('>f8')
# trueFSLMomentum_Z    | double                   | AsDtype('>f8')
# trueFSLTime          | double                   | AsDtype('>f8')
# trueFSLMass          | double                   | AsDtype('>f8')
# trueFSLPdg           | int32_t                  | AsDtype('>i4')
# trueFSLEnergy        | double                   | AsDtype('>f8')
# trueQ2               | double                   | AsDtype('>f8')
# trueCC               | int32_t                  | AsDtype('>i4')
# trueNC               | int32_t                  | AsDtype('>i4')
# trueQEL              | int32_t                  | AsDtype('>i4')
# trueRES              | int32_t                  | AsDtype('>i4')
# trueDIS              | int32_t                  | AsDtype('>i4')
# trueCOH              | int32_t                  | AsDtype('>i4')
# trueMEC              | int32_t                  | AsDtype('>i4')
# trueNeutrons         | int32_t                  | AsDtype('>i4')
# trueProtons          | int32_t                  | AsDtype('>i4')
# truePi0              | int32_t                  | AsDtype('>i4')
# truePiPlus           | int32_t                  | AsDtype('>i4')
# truePiPlusCher       | int32_t                  | AsDtype('>i4')
# truePiMinus          | int32_t                  | AsDtype('>i4')
# truePiMinusCher      | int32_t                  | AsDtype('>i4')
# trueKPlus            | int32_t                  | AsDtype('>i4')
# trueKPlusCher        | int32_t                  | AsDtype('>i4')
# trueKMinus           | int32_t                  | AsDtype('>i4')
# trueKMinusCher       | int32_t                  | AsDtype('>i4')
# passTrueCC           | int32_t                  | AsDtype('>i4')
# passBeamOK           | int32_t                  | AsDtype('>i4')
# passBRFWindow        | int32_t                  | AsDtype('>i4')
# passMissingPPSTick   | int32_t                  | AsDtype('>i4')
# passRequireLAPPD     | int32_t                  | AsDtype('>i4')
# passPairedEvent      | int32_t                  | AsDtype('>i4')
# passPromptPMTCluster | int32_t                  | AsDtype('>i4')
# passHighQualityPM... | int32_t                  | AsDtype('>i4')
# passMRDTrackRecon... | int32_t                  | AsDtype('>i4')
# passMRDRecoTrack     | int32_t                  | AsDtype('>i4')
# passTankMRDCoinc     | int32_t                  | AsDtype('>i4')
# passMuonTopology     | int32_t                  | AsDtype('>i4')
# passNoVeto           | int32_t                  | AsDtype('>i4')

# %%
mask = mcEvents["trueCC"] == 1
mcEvents["trueMuonEnergy"][mask]
# Out:
# <Array [328, 532, 1.41e+03, 255, ..., 300, 734, 246] type='111339 * float64'>

# %%
rows = []  # tablo satırlarını tutacak liste

# başlangıç maskesi: tüm eventler True (hiç cut yok)
current_mask = ak.ones_like(mcEvents["trueCC"], dtype=bool)

# -------- No cut --------

# CC ve NC eventleri ayır
cc_mask = (mcEvents["trueCC"] == 1) & current_mask
nc_mask = (mcEvents["trueCC"] == 0) & current_mask

# enerji değerlerini al
cc_energy = mcEvents["trueMuonEnergy"][cc_mask]
nc_energy = mcEvents["trueMuonEnergy"][nc_mask]

# ortalama enerjileri hesapla
mean_cc = ak.mean(cc_energy)
mean_nc = ak.mean(nc_energy)

# None ise -1 yap, değilse float'a çevir
mean_cc = float(mean_cc) if mean_cc is not None else -1
mean_nc = float(mean_nc) if mean_nc is not None else -1

# ilk satırı ekle (cut yok)
rows.append({
    "Cut": "No cut",
    "CC Event": int(ak.sum(cc_mask)),  # CC event sayısı
    "NC Event": int(ak.sum(nc_mask)),  # NC event sayısı
    "True mean muon energy (CC)": mean_cc,         # CC ortalama enerji
    "True mean muon energy (NC)": mean_nc          # NC ortalama enerji
})

# -------- cumulative cuts --------
cuts = [
    #"passBeamOK",
    #"passBRFWindow",
    #"passPPSMissing",
    #"passRequireLAPPD",
    "passPairedEvent",
    "passPromptPMTCluster",
    "passHighQualityPMTCluster",
    "passTankMRDCoinc",
    "passMRDRecoTrack",
    #"passMRDTrackReconstructed",

    #"passMuonTopology",
    #"passNoVeto",
]

for cut in cuts:
    # mevcut maskeye yeni cut ekle (kümülatif)
    current_mask = current_mask & (mcEvents[cut] == 1)

    # cut sonrası CC ve NC ayır
    cc_mask = (mcEvents["trueCC"] == 1) & current_mask
    nc_mask = (mcEvents["trueCC"] == 0) & current_mask

    # enerji değerlerini al
    cc_energy = mcEvents["trueMuonEnergy"][cc_mask]
    nc_energy = mcEvents["trueMuonEnergy"][nc_mask]

    # ortalama enerji hesapla
    mean_cc = ak.mean(cc_energy)
    mean_nc = ak.mean(nc_energy)

    # None kontrolü + float dönüşümü
    mean_cc = float(mean_cc) if mean_cc is not None else -1
    mean_nc = float(mean_nc) if mean_nc is not None else -1

    # tabloya yeni satır ekle
    rows.append({
        "Cut": cut,
        "CC Event": int(ak.sum(cc_mask)),
        "NC Event": int(ak.sum(nc_mask)),
        "True mean muon energy (CC)": mean_cc,
        "True mean muon energy (NC)": mean_nc
    })

# listeyi pandas DataFrame'e çevir
cutflowTable = pd.DataFrame(rows)

# toplam event sayısı
cutflowTable["Total"] = cutflowTable["CC Event"] + cutflowTable["NC Event"]

# CC oranı (%)
cutflowTable["CC Ratio [%]"] = 100 * cutflowTable["CC Event"] / cutflowTable["Total"]

# sütun sırasını düzenle (energy en sağda)
cutflowTable = cutflowTable[
    ["Cut", "CC Event", "NC Event", "Total", "CC Ratio [%]",
     "True mean muon energy (CC)", "True mean muon energy (NC)"]
]

# tabloyu göster
cutflowTable
# Out:
#                          Cut  CC Event  NC Event   Total  CC Ratio [%]  \
# 0                     No cut    111339     48661  160000     69.586875
# 1            passPairedEvent    111339     48661  160000     69.586875
# 2       passPromptPMTCluster     94530     28388  122918     76.904928
# 3  passHighQualityPMTCluster     37757      8890   46647     80.941968
# 4           passTankMRDCoinc      6935       275    7210     96.185853
# 5           passMRDRecoTrack      5593        88    5681     98.450977
#
#    True mean muon energy (CC)  True mean muon energy (NC)
# 0                  660.539967                -9996.645325
# 1                  660.539967                -9996.645325
# 2                  664.665713                -9996.467344
# 3                  703.758419                -9994.404007
# 4                 1347.540799                -9962.578824
# 5                 1422.342532                -9885.183825

# %%
energy_branch = "trueMuonEnergy"

plt.figure()

mask = ak.ones_like(mcEvents["trueCC"], dtype=bool)

# No cut
plt.hist(ak.to_numpy(mcEvents["trueMuonEnergy"][mask]),
         bins=500, range=(0,6000),
         histtype="step",
         label="No cut")

for i, cut in enumerate(cuts, start=1):
    
    mask = mask & (mcEvents[cut] == 1)
    energy_values = ak.to_numpy(mcEvents["trueMuonEnergy"][mask])
    
    label = f"Cut {i}: {cut}"
    
    plt.hist(energy_values,
             bins=500, range=(0,6000),
             histtype="step",
             label=label)

plt.xlabel("True Muon Energy [GeV]")
plt.ylabel("Events")
plt.title("Cutflow - True Muon Energy")
plt.legend(fontsize=8)
plt.grid(True)
plt.show()

# %%
plt.figure()

energy_branch = "trueMuonEnergy"

# SADECE CC seçimi
mask = (mcEvents["trueCC"] == 0)

# No cut (ama zaten sadece CC)
plt.hist(ak.to_numpy(mcEvents[energy_branch][mask]),
         bins=500, range=(0,6000),
         histtype="step",
         label="No cut (CC only)")

# Cutları uygula
for i, cut in enumerate(cuts, start=1):
    
    mask = mask & (mcEvents[cut] == 1)

    energy_values = ak.to_numpy(mcEvents[energy_branch][mask])
    
    label = f"Cut {i}"
    
    plt.hist(energy_values,
             bins=500, range=(0,6000),
             histtype="step",
             label=label)

plt.xlabel("True Muon Energy [GeV]")
plt.ylabel("Events")
#plt.yscale("log")
plt.title("Cutflow - True Muon Energy (CC only)")
plt.legend()
plt.grid(True)

plt.show()

# %%
print(len(mcEvents[(mcEvents["trueCC"] == 0)]))
print(len(mcEvents[(mcEvents["trueCC"] == 0) & (mcEvents["passMRDTrackReconstructed"] == 1)]))
# Out:
# 12139
# 742

# %%
#NC durumunda zaten muon yok -999 geliyor fakat histo pozitif yapiyor onu

energy_branch = "trueMuonEnergy"

# sadece NC seçimi (senin dediğin gibi trueNC == 1)
mask = (mcEvents["trueNC"] == 1)

energy_values = ak.to_numpy(mcEvents[energy_branch][mask])

plt.figure()
plt.hist(energy_values,
         bins=500,
         #range=(0, 6000),
         histtype="step")

plt.xlabel("True Muon Energy")
plt.ylabel("Events")
plt.title("True Muon Energy (NC only)")
plt.grid(True)

plt.show()

# %%
energy_values
# Out:
# array([-9999.        , -9999.        , -9999.        , ...,
#        -9999.        ,   382.66885376, -9999.        ], shape=(12139,))
